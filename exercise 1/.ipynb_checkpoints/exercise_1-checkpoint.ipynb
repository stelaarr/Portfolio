# %% [markdown]
# # Exercise 1
# Use Elasticsearch to index and query the RateBeer dataset (directory data/ratebeer). The dataset contains textual reviews of beers and ratings assigned by multiple users.

# %%
import pandas as pd
import re
import json
import time
import requests
from requests.auth import HTTPBasicAuth
from elasticsearch import Elasticsearch
import elasticsearch
from elasticsearch.helpers import bulk

print(elasticsearch.__version__)
# Out:
# (8, 12, 0)

# %% [markdown]
# I'll be re-using code provided for the exercise lecture 02.12.2024.

# %%
USER = 'elastic'
PWD = 'GHafZMbVQ*cgYBz7n7pT'
index_name = 'beers'
ES_ENDPOINT = 'https://localhost:9200'

path_to_ca_certificates = 'C:/Users/Usuario/OneDrive/Escritorio/Data in Production/elastic_search/elasticsearch-8.12.0/config/certs/http_ca.crt'

# %% [markdown]
# ### Load the data efficiently and index the data

# %%
df = pd.read_csv('../data/ratebeer/ratebeer.csv')
df.head()
# Out:
#                          beer_name            beer_style beer_ABV  \
# 0            Sierra Nevada Bigfoot           Barley Wine      9.6
# 1                         Icehouse            Pale Lager      5.5
# 2  St Georges Paragon Steam Bitter     California Common        4
# 3               Ayinger Bru-Weisse     German Hefeweizen      5.1
# 4           Great Divide Titan IPA  India Pale Ale (IPA)      7.1
#
#    review_appearance  review_aroma  review_palate  review_taste  \
# 0                  5             7              4             7
# 1                  3             2              1             1
# 2                  3             3              3             6
# 3                  5             8              5             8
# 4                  3             7              4             8
#
#    review_overall review_profileName  \
# 0              15            Juancho
# 1               1              xav33
# 2              10             hughie
# 3              15           jredmond
# 4              16          gringo332
#
#                                          review_text
# 0  Draught \tThe big boy from Sierra Nevada. Nice...
# 1  Icehouse\tDeuce-Deuce\tRecent browing, resided...
# 2  Cask at Wellington Arms, Bedford. Gold with a ...
# 3  500mL Bottle. 2nd of 13 for the night. Body is...
# 4  Bottle. Pours golden/orange with a small white...

# %% [markdown]
# ### EDA
#
# Let's check if there are duplicated, nan values and any other possible entry not interesting

# %%
# Are there duplicates?
len(df[df.duplicated()])
# Out:
# 2784

# %%
df[df.duplicated()]
# Out:
#                                           beer_name            beer_style  \
# 6911                                        Olympia            Pale Lager
# 15677                                 Dundee Porter                Porter
# 23600                         Ass Kisser Double IPA   Imperial/Double IPA
# 24195             HeBrew Bittersweet Lennys R.I.P.A   Imperial/Double IPA
# 36266                                 Dundee Porter                Porter
# ...                                             ...                   ...
# 584295                                      Schlitz            Pale Lager
# 584323                  Leelanau Good Harbor Golden         Bire de Garde
# 584368            Spanish Peaks Honey Raspberry Ale            Fruit Beer
# 584414                  McSorleys Irish Black Lager           Schwarzbier
# 584618  Buffalo Bills Americas Original Pumpkin Ale  Spice/Herb/Vegetable
#
#        beer_ABV  review_appearance  review_aroma  review_palate  review_taste  \
# 6911        4.8                  5             4              2             5
# 15677       6.5                  3             6              3             6
# 23600      7.75                  3             5              3             5
# 24195        10                  4             7              3             8
# 36266       6.5                  3             6              3             7
# ...         ...                ...           ...            ...           ...
# 584295      4.6                  1             1              2             2
# 584323      7.5                  4             8              4             8
# 584368      4.7                  3             7              3             7
# 584414      5.5                  4             7              4             9
# 584618      5.2                  3             6              3             6
#
#         review_overall review_profileName  \
# 6911                20        AndrewKitna
# 15677               13          Swalden28
# 23600               16             Fred82
# 24195               16              vyvvy
# 36266               12          badlizard
# ...                ...                ...
# 584295               1            seymour
# 584323              15            MrBendo
# 584368              12        Drinkingdan
# 584414              18               Odyn
# 584618              12             MadMan
#
#                                               review_text
# 6911    Come on, its OLY. You should know what your ge...
# 15677   (12oz bottle, courtesy of jjfoodie) Pours a da...
# 23600   Bottle from Winooski..\tAppearance : Hazy ambe...
# 24195   Pours clear deep bronze with a decent sized ta...
# 36266   Bottle from Bevmo.  Dark brown with no head.  ...
# ...                                                   ...
# 584295  Tasted directly from can before adding it to a...
# 584323  Thanks to RagallachMC for the 750. Straw color...
# 584368  Sweet, and rapberrys are very present during t...
# 584414  Really good, easy drinking lager.  A little bi...
# 584618  Bottle. Pours more of an orange colored amber ...
#
# [2784 rows x 10 columns]

# %% [markdown]
# A quick exploration on the data shows us that these are really not duplicates as the ratings and review comments are differents.

# %%
# Nan values?
nan_values = df.isna().sum()
nan_values
# Out:
# beer_name                0
# beer_style               0
# beer_ABV                 0
# review_appearance        0
# review_aroma             0
# review_palate            0
# review_taste             0
# review_overall           0
# review_profileName       0
# review_text           1003
# dtype: int64

# %%
df['review_text'].fillna(' ', inplace=True) # the data has nan values in review_text so we fill them with blank space to be able to index

# %% [markdown]
# ### Prepare data to index

# %%
#transform dataframe into json format
docs = df.to_dict(orient='records')
doc_ids = df.index
print(doc_ids)
print(docs[1703])
# Out:
# RangeIndex(start=0, stop=584833, step=1)
# {'beer_name': 'J.W. Lees Harvest Ale (Port)', 'beer_style': 'Barley Wine', 'beer_ABV': '11.5', 'review_appearance': 3, 'review_aroma': 8, 'review_palate': 4, 'review_taste': 8, 'review_overall': 15, 'review_profileName': 'Rockinout', 'review_text': 'Aged 8 months. Translucent golden brown color, no head. Traces of vanilla, maple, nut, raisin all blended together. Velvetly smooth on the palate, finished with a touch of alcohol.'}

# %%
docs[88]
# Out:
# {'beer_name': 'Amstel Light',
#  'beer_style': 'Pale Lager',
#  'beer_ABV': '3.5',
#  'review_appearance': 3,
#  'review_aroma': 4,
#  'review_palate': 1,
#  'review_taste': 2,
#  'review_overall': 3,
#  'review_profileName': 'RobertVerloop99',
#  'review_text': ' '}

# %% [markdown]
# ### Index the data

# %% [markdown]
# ElasticSearch Wrapper for Python

# %%
class Elastic:
    """
    A convenience object to send HTTP requests to Elasticsearch
    """
    def __init__(self, endpoint, username, password, path_to_ca_certificates):
        """
        @param endpoint: the URL of the Elasticsearch instance
        @param username: the Elasticsearch username 
        @param password: the Elasticsearch password
        """
        self.header = {'Content-Type': 'application/json', 'charset':'UTF-8'}
        #self.header={'Content-Type': '--data-binary application/x-ndjson'}
        self.endpoint = endpoint
        self.username = username
        self.password = password
        self.path_to_ca_certificates = path_to_ca_certificates
        self.methods_mapping = {'get': requests.get, 
                                'put':requests.put, 
                                'post':requests.post, 
                                'delete':requests.delete}
        
    def curl(self, method, handle, json=None):
        """
        Sends an HTTP request to the Elasticsearch instance
        @param method: can be 'get', 'put', 'post', 'delete'
        @param handle: the API handle to be appended to the Elasticsearch url
        @param json: the json payload of the HTTP request
        """
        http_method = self.methods_mapping[method.lower()]
        r = http_method(f'{self.endpoint}/{handle}', auth=HTTPBasicAuth(USER, PWD), 
                        headers=self.header, json=json,
                        verify = self.path_to_ca_certificates)
        return r

# %% [markdown]
# Defining all settings before indexing our data:
#
# - Mapping: define all entries data type to allow for full text search on the review text and beer name, and should allow
# filtering by beer style
#
# - As a relevance metric, I chose BM25 and increased by 10% the amount
# of length discounting compared to the default value

# %%
# create an index
create_index_json={
  "mappings" : {
      "properties" : {
        "beer_name" :  {
            "type": "text",  #for full-text searches
            "fields": {
              "keyword": {    
                  "type": "keyword" #for exact search
          }}},
        "beer_style" : {
            "type": "text",  #for full-text searches
            "fields": {
              "keyword": {    
                  "type": "keyword" #for exact search
          }}},
        "beer_ABV" : {
          "type" : "text"
        },
        "review_appearance" : {
          "type" : "long"
        },
        "review_aroma" : {
          "type" : "long"
        },
        "review_palate" : {
          "type" : "long"
        },
        "review_taste" : {
          "type" : "long"
        },
        "review_overall" : {
          "type" : "long"
        },
        "review_profileName" : {
          "type" : "text"
        },
        "review_text" : {
          "type" : "text"
        }
      }
  },
  "settings": {
        "number_of_replicas": 1, # only one replica needed
        "refresh_interval": -1, # static dataset and updated rarely so we disable the refreshing
        "index" : {
        "similarity" : {
          "default" : {
            "type" : "BM25", "b": 0.75, "k1": 1.1 # 10% increase of the default value
          }
        }
    },
        "analysis": {
            "analyzer": {"std_english": {"type": "standard", "stopwords": "_english_" }}
        }
  }}

# %%
e = Elastic(ES_ENDPOINT, USER, PWD, path_to_ca_certificates)

# %%
# to avoid error delete index
r = e.curl('delete', index_name)
r.json()
# Out:
# {'acknowledged': True}

# %%
# create an index
r = e.curl('put', index_name, json=create_index_json)
r.json()
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'beers'}

# %%
# get the index details and settings
r = e.curl('get', index_name)
r.json()
# Out:
# {'beers': {'aliases': {},
#   'mappings': {'properties': {'beer_ABV': {'type': 'text'},
#     'beer_name': {'type': 'text', 'fields': {'keyword': {'type': 'keyword'}}},
#     'beer_style': {'type': 'text', 'fields': {'keyword': {'type': 'keyword'}}},
#     'review_appearance': {'type': 'long'},
#     'review_aroma': {'type': 'long'},
#     'review_overall': {'type': 'long'},
#     'review_palate': {'type': 'long'},
#     'review_profileName': {'type': 'text'},
#     'review_taste': {'type': 'long'},
#     'review_text': {'type': 'text'}}},
#   'settings': {'index': {'routing': {'allocation': {'include': {'_tier_preference': 'data_content'}}},
#     'refresh_interval': '-1',
#     'number_of_shards': '1',
#     'provided_name': 'beers',
#     'similarity': {'default': {'type': 'BM25', 'b': '0.75', 'k1': '1.1'}},
#     'creation_date': '1716627436673',
#     'analysis': {'analyzer': {'std_english': {'type': 'standard',
#        'stopwords': '_english_'}}},
#     'number_of_replicas': '1',
#     'uuid': '-cCIiDYDR3S85Du9A2K5KA',
#     'version': {'created': '8500008'}}}}}

# %% [markdown]
# To efficiently load the data we use bulk indexing:

# %%
# bulk indexing (via official API)

#connect to the local elasticsearch node and authenticate
es = Elasticsearch([ES_ENDPOINT], ca_certs=path_to_ca_certificates, basic_auth=(USER, PWD))

actions = [
  {
    "_index": index_name,
    "_id": doc_id,
    "_source": doc
  }
  for doc_id, doc in list(zip(doc_ids, docs))
]

# send actions in bulk (the API takes care of chunking them optimally)
bulk(es, actions)
# Out:
# (584833, [])

# %% [markdown]
# Refresh to load the data

# %%
# reset the refresh interval to 2 seconds to allow the bulk data to be loaded
r = e.curl('put', f'{index_name}/_settings', {'index' : {'refresh_interval' : '2s'}})
r.json()
# Out:
# {'acknowledged': True}

# %% [markdown]
# Small check for beer 88, to see if it loaded

# %%
r = e.curl('get', f'{index_name}/_doc/{doc_ids[88]}')
r.json()['_source']
# Out:
# {'beer_name': 'Amstel Light',
#  'beer_style': 'Pale Lager',
#  'beer_ABV': '3.5',
#  'review_appearance': 3,
#  'review_aroma': 4,
#  'review_palate': 1,
#  'review_taste': 2,
#  'review_overall': 3,
#  'review_profileName': 'RobertVerloop99',
#  'review_text': ' '}

# %%
# empty query
r = e.curl('get', f'{index_name}/_search')
r.json()
# Out:
# {'took': 13,
#  'timed_out': False,
#  '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0},
#  'hits': {'total': {'value': 10000, 'relation': 'gte'},
#   'max_score': 1.0,
#   'hits': [{'_index': 'beers',
#     '_id': '0',
#     '_score': 1.0,
#     '_source': {'beer_name': 'Sierra Nevada Bigfoot',
#      'beer_style': 'Barley Wine',
#      'beer_ABV': '9.6',
#      'review_appearance': 5,
#      'review_aroma': 7,
#      'review_palate': 4,
#      'review_taste': 7,
#      'review_overall': 15,
#      'review_profileName': 'Juancho',
#      'review_text': 'Draught \tThe big boy from Sierra Nevada. Nice hazy dark amber color, not much of head but more than the bottle (if i  recall correctly) Nicely balanced, huge hops, nice barley wine sweetness.'}},
#    {'_index': 'beers',
#     '_id': '1',
#     '_score': 1.0,
#     '_source': {'beer_name': 'Icehouse',
#      'beer_style': 'Pale Lager',
#      'beer_ABV': '5.5',
#      'review_appearance': 3,
#      'review_aroma': 2,
#      'review_palate': 1,
#      'review_taste': 1,
#      'review_overall': 1,
#      'review_profileName': 'xav33',
#      'review_text': 'Icehouse\tDeuce-Deuce\tRecent browing, resided in 11/06\tMedium pour in a pint glass.\t\tPoured a slightly pale yellow with a fizzy mostly diminishing white head.\t\tSmelt of faint grain. \t\tTaste was upfront sweet drainage water with maybe hints of grain flavoring followed by an execrable harsh bitter fat mans bat tub water taste.  Mouthfeel was light bodied, watery-ish, fizzy and strongly astringent on the finish.\t\tOverall, I never actually tasted this beer until today.  Ive drank it a few times and thought it was ok, but never *tasted* it.  Dont taste it.  Just enjoy the buzz.'}},
#    {'_index': 'beers',
#     '_id': '2',
#     '_score': 1.0,
#     '_source': {'beer_name': 'St Georges Paragon Steam Bitter',
#      'beer_style': 'California Common',
#      'beer_ABV': '4',
#      'review_appearance': 3,
#      'review_aroma': 3,
#      'review_palate': 3,
#      'review_taste': 6,
#      'review_overall': 10,
#      'review_profileName': 'hughie',
#      'review_text': 'Cask at Wellington Arms, Bedford. Gold with a small white head. Some sulphur in the aroma. Sweet malt taste with some fruity sourness. Mid to sharp bitter finish.'}},
#    {'_index': 'beers',
#     '_id': '3',
#     '_score': 1.0,
#     '_source': {'beer_name': 'Ayinger Bru-Weisse',
#      'beer_style': 'German Hefeweizen',
#      'beer_ABV': '5.1',
#      'review_appearance': 5,
#      'review_aroma': 8,
#      'review_palate': 5,
#      'review_taste': 8,
#      'review_overall': 15,
#      'review_profileName': 'jredmond',
#      'review_text': '500mL Bottle. 2nd of 13 for the night. Body is cloudy with white foamy head. Aroma is wheat and yeast.  Taste is citrus, wheat and yeast....some traces of banana.'}},
#    {'_index': 'beers',
#     '_id': '4',
#     '_score': 1.0,
#     '_source': {'beer_name': 'Great Divide Titan IPA',
#      'beer_style': 'India Pale Ale (IPA)',
#      'beer_ABV': '7.1',
#      'review_appearance': 3,
#      'review_aroma': 7,
#      'review_palate': 4,
#      'review_taste': 8,
#      'review_overall': 16,
#      'review_profileName': 'gringo332',
#      'review_text': 'Bottle. Pours golden/orange with a small white head. Piney citrus aroma. Flavor was bold and hoppy and slightly sticky with piney and citrus hops floral notes and some grapefruit with a rich malty backbone.'}},
#    {'_index': 'beers',
#     '_id': '5',
#     '_score': 1.0,
#     '_source': {'beer_name': 'Spaten Optimator',
#      'beer_style': 'Doppelbock',
#      'beer_ABV': '7.6',
#      'review_appearance': 5,
#      'review_aroma': 9,
#      'review_palate': 2,
#      'review_taste': 8,
#      'review_overall': 18,
#      'review_profileName': 'LordNeuf',
#      'review_text': 'A strong pungent aroma of a classic bock cailbre beer. Deep cola like copper/amber appearance. The flavor is quite strong and very malty. This leads to the mouth feel being impressivly heavy as the flavor lingers longer than a typical schwartzbere. I would highly recommend this with grilled foods and smokey barbeque.'}},
#    {'_index': 'beers',
#     '_id': '6',
#     '_score': 1.0,
#     '_source': {'beer_name': 'A1A Aleworks Red Brick Ale',
#      'beer_style': 'Amber Ale',
#      'beer_ABV': '5.42',
#      'review_appearance': 4,
#      'review_aroma': 6,
#      'review_palate': 3,
#      'review_taste': 6,
#      'review_overall': 12,
#      'review_profileName': 'kp',
#      'review_text': 'Date: 11/18/2007\tMode: Draft\tSource: Brewpub\t\tclear amber, creamy beige head, lots of scattered lace, \tsweet crystal and caramel malt aroma with citrus and floral hops, \trich caramel malt flavor, bready character, touch of caramel sweetness, growing butterscotch in the sweetness, well balanced by citrus hops, lasting bitter finish, \t\tAroma: 6/10; Appearance: 7/10; Flavor: 6/10; Palate: 6/10; Overall: 12/20\tRating: 3.1/5.0Drinkability: 8/10\tScore: *4'}},
#    {'_index': 'beers',
#     '_id': '7',
#     '_score': 1.0,
#     '_source': {'beer_name': 'Big Horn Hefeweizen',
#      'beer_style': 'German Hefeweizen',
#      'beer_ABV': '-',
#      'review_appearance': 3,
#      'review_aroma': 6,
#      'review_palate': 4,
#      'review_taste': 7,
#      'review_overall': 14,
#      'review_profileName': 'gws57',
#      'review_text': 'Had this one at the brewpub in Schaumburg, Illinois.  Cloudy medium yellow pour with a thick, foamy head, clove and honey sweetness with lots of banana.  Strong!  Very good hefe.'}},
#    {'_index': 'beers',
#     '_id': '8',
#     '_score': 1.0,
#     '_source': {'beer_name': 'Rogue Dead Guy Ale',
#      'beer_style': 'Heller Bock',
#      'beer_ABV': '6.6',
#      'review_appearance': 4,
#      'review_aroma': 6,
#      'review_palate': 3,
#      'review_taste': 7,
#      'review_overall': 13,
#      'review_profileName': 'devilben02',
#      'review_text': 'Pours a rich amber color with a huge, foamy, eggshell-white head that settles to a persistent thin film. The aroma is a complex but somewhat dull combination of light citrusy hops, earthy yeast, and a lager-like clean caramel sweetness. The flavor is much more hop-forward, with an assertive yet rounded combination of citrus and pine. A semi-dry, biscuity sweet malt provides some balance, along with a musty yeasty character. The texture is mouth-filling, but there is only a moderate lingering resinous feel, and the finish is actually a bit drying. Overall, this is certainly something different than just another pale ale or IPA to serve as the brewerys flagship, but despite that uniqueness, it just doesnt feel all that special.'}},
#    {'_index': 'beers',
#     '_id': '9',
#     '_score': 1.0,
#     '_source': {'beer_name': 'Rogue Ten Thousand Brew Ale (10,000)',
#      'beer_style': 'Imperial/Double IPA',
#      'beer_ABV': '10',
#      'review_appearance': 4,
#      'review_aroma': 7,
#      'review_palate': 3,
#      'review_taste': 7,
#      'review_overall': 14,
#      'review_profileName': 'jeffc666',
#      'review_text': 'Second in my two part series: Hotel Room Ratings. Boy this bottle sure is fancy. I even had high hopes when I bought this that it was NOT going to be an alias for another Rogue brew, and I have been rewarded. The bottle is quite fancy. Pours a hazy orange with a nice big dense on the edges, pillowy in the middle, head. The aroma is hoppy, citrus and herbs, some interesting malt aromas that do not exactly marry that well with the hops. The flavor is first and foremost about the hops. There is a good amount of malt, but it is a bit muddled. Earthy with some sweetness. Alcohol is evident, maybe a tad harsh in this respect. Overall a bit coarse but in the end still enjoyable and above average. For the price point and the occasion that it commemorates, I was hoping for more.'}}]}}

# %% [markdown]
# Since the database is quite static we set off the refresh

# %%
# reset the refresh interval to -1 so no new updates since the
r = e.curl('put', f'{index_name}/_settings', {'index' : {'refresh_interval' : -1}})
r.json()
# Out:
# {'acknowledged': True}

# %% [markdown]
# ## Queries

# %% [markdown]
# 1.6 Function for an exact-match query on the beer name

# %%
def em_query(text):
    exc = {
      "query": {
        "match_phrase": {
            "beer_name": {
                "query": text
            }
        }
      }
    }
    return exc

# %%
# example on beer Amstel Light
exact_mat = em_query('Amstel Light')
rc = e.curl('get', f'{index_name}/_search', exact_mat)
rc.json()['hits']['hits']
# Out:
# [{'_index': 'beers',
#   '_id': '88',
#   '_score': 14.704899,
#   '_source': {'beer_name': 'Amstel Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '3.5',
#    'review_appearance': 3,
#    'review_aroma': 4,
#    'review_palate': 1,
#    'review_taste': 2,
#    'review_overall': 3,
#    'review_profileName': 'RobertVerloop99',
#    'review_text': ' '}},
#  {'_index': 'beers',
#   '_id': '7174',
#   '_score': 14.704899,
#   '_source': {'beer_name': 'Amstel Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '3.5',
#    'review_appearance': 3,
#    'review_aroma': 4,
#    'review_palate': 4,
#    'review_taste': 6,
#    'review_overall': 12,
#    'review_profileName': 'davidoc',
#    'review_text': 'Im not sure why this beers slogan would necessarily apply, or why an import would always be better than a domestic. Not bad, but 3.5% is pretty weak.'}},
#  {'_index': 'beers',
#   '_id': '14318',
#   '_score': 14.704899,
#   '_source': {'beer_name': 'Amstel Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '3.5',
#    'review_appearance': 1,
#    'review_aroma': 2,
#    'review_palate': 1,
#    'review_taste': 2,
#    'review_overall': 2,
#    'review_profileName': 'jstu9',
#    'review_text': 'I remember liking this once a upon a time. Not quite sure why though.'}},
#  {'_index': 'beers',
#   '_id': '16301',
#   '_score': 14.704899,
#   '_source': {'beer_name': 'Amstel Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '3.5',
#    'review_appearance': 2,
#    'review_aroma': 4,
#    'review_palate': 2,
#    'review_taste': 4,
#    'review_overall': 16,
#    'review_profileName': 'Leighton',
#    'review_text': 'Bottle. Pours clear, faint yellow with a small, fizzy white head. Light bread and sugar aroma. Mildly sweet flavor. Light body with lively carbonation. A decent light beer option.'}},
#  {'_index': 'beers',
#   '_id': '16638',
#   '_score': 14.704899,
#   '_source': {'beer_name': 'Amstel Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '3.5',
#    'review_appearance': 2,
#    'review_aroma': 3,
#    'review_palate': 2,
#    'review_taste': 3,
#    'review_overall': 5,
#    'review_profileName': 'Onslow',
#    'review_text': 'Pour from a 12 oz bottle. Pale yellow beer with two fingers of white head. Weak aroma of sweet grain. Watery. Not much flavor - weak grain and hint of hops. Not much here.'}},
#  {'_index': 'beers',
#   '_id': '33239',
#   '_score': 14.704899,
#   '_source': {'beer_name': 'Amstel Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '3.5',
#    'review_appearance': 3,
#    'review_aroma': 4,
#    'review_palate': 2,
#    'review_taste': 4,
#    'review_overall': 7,
#    'review_profileName': 'zathrus13',
#    'review_text': 'Yellow/gold, with a white head. Aromas are malt and grain. Flavors are light malt, grain, and a little pepper. Very light on the palate.'}},
#  {'_index': 'beers',
#   '_id': '36956',
#   '_score': 14.704899,
#   '_source': {'beer_name': 'Amstel Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '3.5',
#    'review_appearance': 2,
#    'review_aroma': 4,
#    'review_palate': 3,
#    'review_taste': 4,
#    'review_overall': 7,
#    'review_profileName': 'tsarman',
#    'review_text': 'Best light beer...probably. But thats like saying best poison or best way to castrate oneself.  Its a prize but it shouldnt be something to brag about.  I actually like it better than Heineken.'}},
#  {'_index': 'beers',
#   '_id': '38898',
#   '_score': 14.704899,
#   '_source': {'beer_name': 'Amstel Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '3.5',
#    'review_appearance': 3,
#    'review_aroma': 4,
#    'review_palate': 3,
#    'review_taste': 5,
#    'review_overall': 9,
#    'review_profileName': 'kwoeltje',
#    'review_text': '(bottle) Pale lager gold (deeper than most light beers) with white head. Not much aroma. Flavor fairly crisp. Better than the vast majority of light beers.'}},
#  {'_index': 'beers',
#   '_id': '42477',
#   '_score': 14.704899,
#   '_source': {'beer_name': 'Amstel Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '3.5',
#    'review_appearance': 2,
#    'review_aroma': 3,
#    'review_palate': 2,
#    'review_taste': 5,
#    'review_overall': 5,
#    'review_profileName': 'GAManiac',
#    'review_text': 'Poured a pale watery yellow with a one-finger white head that dissipated extremely quickly.  Typical Euro lagor smells - corn, malt, barley. Skunky if nothing else.  Some malt flavor and a hint of lemony hops....maybe. Not terrible for the style.  Extremely watered down and light feel. I almost think this could be a more respectable brew if it wasnt so watered down.   If you take it for what it is, a macro lager, you could do much worse. Im not going out of my way to get it, but I could see myself knocking a few of these back on the golf course in the summer. Tolerable at best though.'}},
#  {'_index': 'beers',
#   '_id': '45422',
#   '_score': 14.704899,
#   '_source': {'beer_name': 'Amstel Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '3.5',
#    'review_appearance': 3,
#    'review_aroma': 5,
#    'review_palate': 3,
#    'review_taste': 6,
#    'review_overall': 11,
#    'review_profileName': 'pwyman',
#    'review_text': 'Light pilsner flavor. Smooth over the tongue with no after taste. Quite pleasant for  a light beer.'}}]

# %% [markdown]
# 1.7 Function for a full-text query on beer name and review, with review boosted by a factor 1.7 compared to beer
# name

# %%
def ft_query(text, boost):
    exc = {
      "query": {
        "multi_match" : {
          "query":  text, 
          #"type": "phrase",
          "fields": [ "beer_name", f"review_text^{boost}" ] 
        }
      }
    }
    return exc

# %%
# example on beer Sierra Nevada
ft_mat = ft_query('Sierra Nevada', 1.7)
ra = e.curl('get', f'{index_name}/_search', ft_mat)
ra.json()['hits']['hits']
# Out:
# [{'_index': 'beers',
#   '_id': '391298',
#   '_score': 35.98211,
#   '_source': {'beer_name': 'Sierra Nevada Celebration Ale',
#    'beer_style': 'India Pale Ale (IPA)',
#    'beer_ABV': '6.8',
#    'review_appearance': 3,
#    'review_aroma': 7,
#    'review_palate': 3,
#    'review_taste': 8,
#    'review_overall': 13,
#    'review_profileName': 'brianjames1',
#    'review_text': 'On tap at Pizza Port Brewing Co in Carlsbad as Sierra Nevada Torpedo Ale. Delicious. Best brew by Sierra Nevada.'}},
#  {'_index': 'beers',
#   '_id': '139183',
#   '_score': 35.350056,
#   '_source': {'beer_name': 'Sierra Nevada Pale Ale (Bottle)',
#    'beer_style': 'American Pale Ale',
#    'beer_ABV': '5.6',
#    'review_appearance': 3,
#    'review_aroma': 5,
#    'review_palate': 2,
#    'review_taste': 3,
#    'review_overall': 7,
#    'review_profileName': 'achtungpv',
#    'review_text': "UPDATED: JUL 2, 2003 For years I've heard 'Sierra Nevada this, Sierra Nevada that.' To bad this isn't flavor and that isn't taste."}},
#  {'_index': 'beers',
#   '_id': '494046',
#   '_score': 33.394722,
#   '_source': {'beer_name': 'Sierra Nevada Summerfest',
#    'beer_style': 'Premium Lager',
#    'beer_ABV': '5',
#    'review_appearance': 4,
#    'review_aroma': 7,
#    'review_palate': 2,
#    'review_taste': 4,
#    'review_overall': 10,
#    'review_profileName': 'Malicya',
#    'review_text': 'Really disappointing for Sierra Nevada.  It taste "OK" for a lager beer, nothing to die for.  Its a good fishing beer for a Budweiser Fan ... not for a die-hard Sierra Nevada drinker.'}},
#  {'_index': 'beers',
#   '_id': '318983',
#   '_score': 33.211018,
#   '_source': {'beer_name': 'Sierra Nevada Summerfest',
#    'beer_style': 'Premium Lager',
#    'beer_ABV': '5',
#    'review_appearance': 4,
#    'review_aroma': 6,
#    'review_palate': 4,
#    'review_taste': 8,
#    'review_overall': 18,
#    'review_profileName': 'BeerBaron617',
#    'review_text': 'This is my first Sierra Nevada brew, and I must say, it is quite tasty. It has the drinkability of budweiser, but so much more flavor. I will definitly be buying more Sierra Nevada'}},
#  {'_index': 'beers',
#   '_id': '373712',
#   '_score': 32.149895,
#   '_source': {'beer_name': 'Bear Republic Racer 5',
#    'beer_style': 'India Pale Ale (IPA)',
#    'beer_ABV': '7',
#    'review_appearance': 4,
#    'review_aroma': 7,
#    'review_palate': 3,
#    'review_taste': 6,
#    'review_overall': 15,
#    'review_profileName': 'hilikus83',
#    'review_text': 'To me Racer 5 was dissapointing, it was basically like drinking a sierra nevada pale ale in a Racer 5 bottle. Not saying that sierra nevada is bad, but for an IPA to taste like a regular pale ale, thats bad.'}},
#  {'_index': 'beers',
#   '_id': '451629',
#   '_score': 31.811092,
#   '_source': {'beer_name': 'Sierra Nevada Torpedo Extra IPA',
#    'beer_style': 'India Pale Ale (IPA)',
#    'beer_ABV': '7.2',
#    'review_appearance': 4,
#    'review_aroma': 8,
#    'review_palate': 4,
#    'review_taste': 6,
#    'review_overall': 13,
#    'review_profileName': 'bigred22',
#    'review_text': 'UPDATED: AUG 23, 2010 I prefer the Sierra Nevada standard Pale Ale, but this is quite good in itself.  Definitely very bitter dry finish.  Once again Sierra Nevada gets the perfect hop flavor.  I will definitely have some more of this, very refreshing.'}},
#  {'_index': 'beers',
#   '_id': '95764',
#   '_score': 31.176287,
#   '_source': {'beer_name': 'Sierra Nevada Northern Hemisphere Harvest Wet Hop Ale',
#    'beer_style': 'India Pale Ale (IPA)',
#    'beer_ABV': '6.7',
#    'review_appearance': 4,
#    'review_aroma': 8,
#    'review_palate': 4,
#    'review_taste': 8,
#    'review_overall': 15,
#    'review_profileName': 'pistolpete',
#    'review_text': 'bottle... pours amber... nice hop character.. very drinkable... another good one from sierra nevada'}},
#  {'_index': 'beers',
#   '_id': '333120',
#   '_score': 31.176287,
#   '_source': {'beer_name': 'Hardknott Light Cascade',
#    'beer_style': 'Bitter',
#    'beer_ABV': '3.2',
#    'review_appearance': 4,
#    'review_aroma': 5,
#    'review_palate': 4,
#    'review_taste': 7,
#    'review_overall': 12,
#    'review_profileName': 'louchemobile',
#    'review_text': 'Very creditable session bitter with Cascade quite evident.\t\tLike Sierra Nevada Pale Ale - Lite.'}},
#  {'_index': 'beers',
#   '_id': '554688',
#   '_score': 31.154476,
#   '_source': {'beer_name': 'Redhook Long Hammer IPA',
#    'beer_style': 'India Pale Ale (IPA)',
#    'beer_ABV': '6.5',
#    'review_appearance': 3,
#    'review_aroma': 5,
#    'review_palate': 2,
#    'review_taste': 5,
#    'review_overall': 10,
#    'review_profileName': 'Braincage1',
#    'review_text': 'bottle. Pale amber color topped by a thin white head. Herbal hoppy aroma with the flavor leaning towards the more standard IPA. Some sweetness, some fruit and pine flavor. Bitter finish - this drink just isnt refreshing.  This or a Sierra Nevada? Go with the Sierra Nevada'}},
#  {'_index': 'beers',
#   '_id': '229793',
#   '_score': 30.934422,
#   '_source': {'beer_name': 'Sierra Nevada Northern Hemisphere Harvest Wet Hop Ale',
#    'beer_style': 'India Pale Ale (IPA)',
#    'beer_ABV': '6.7',
#    'review_appearance': 4,
#    'review_aroma': 7,
#    'review_palate': 3,
#    'review_taste': 8,
#    'review_overall': 14,
#    'review_profileName': 'PilsnerPeter',
#    'review_text': 'Bottle 2007: Pours amber/copper with lots of clarity and a tan creamy, bubbly, consistent head. Oily American hop aroma (cascades?) Some subdued orangey citrus and a sweet bready malt background. Light mouth feel. Sweet caramel malt character upfront. Has a mildly toasted middle follwed by that signature Sierra Nevada resiny hop character. Sierra Nevada IPA products seem somewhat homogeneous overall, but for their large scale distribution and low prices I not complaining. A typical, but solid Sierra Nevada IPA.'}}]

# %% [markdown]
# 1.8 Function for a full-text query on the review text, and that filters the results by category

# %%
def ft_query_f(text, filter):
    exc = {
      "query": {
        "bool" : {
          "must" : {
            "match" : { "review_text" : text }
          },
          "filter": {
            "match" : { "beer_style" : filter }
          }
        }
      }
    }
    return exc

# %%
# example on beer Icehouse and beer type Pale Lager
ft_lager = ft_query_f('Icehouse', 'Pale Lager')
rb = e.curl('get', f'{index_name}/_search', ft_lager)
rb.json()['hits']['hits']
# Out:
# [{'_index': 'beers',
#   '_id': '359066',
#   '_score': 13.318455,
#   '_source': {'beer_name': 'Icehouse',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '5.5',
#    'review_appearance': 1,
#    'review_aroma': 2,
#    'review_palate': 1,
#    'review_taste': 1,
#    'review_overall': 3,
#    'review_profileName': 'psychodrama311',
#    'review_text': 'what happened to the good old american beer? the one that doesnt rip off their formula from europe. well for some reason they put water in it. like icehouse for example. i love the description of no watered-down taste. have the people actually tasted icehouse..lol.'}},
#  {'_index': 'beers',
#   '_id': '161519',
#   '_score': 13.19154,
#   '_source': {'beer_name': 'Icehouse Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '5',
#    'review_appearance': 1,
#    'review_aroma': 1,
#    'review_palate': 1,
#    'review_taste': 1,
#    'review_overall': 1,
#    'review_profileName': '666seth',
#    'review_text': 'Even worse than the regular Icehouse. Stay away! Your better off buying carbonated water (cheaper)'}},
#  {'_index': 'beers',
#   '_id': '180881',
#   '_score': 12.67334,
#   '_source': {'beer_name': 'Icehouse Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '5',
#    'review_appearance': 2,
#    'review_aroma': 2,
#    'review_palate': 1,
#    'review_taste': 2,
#    'review_overall': 4,
#    'review_profileName': 'jrallen34',
#    'review_text': 'Icehouse isnt bad enough, they had to make this? watery but with a ton of alcohol, not a fan'}},
#  {'_index': 'beers',
#   '_id': '57802',
#   '_score': 12.550091,
#   '_source': {'beer_name': 'Icehouse Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '5',
#    'review_appearance': 2,
#    'review_aroma': 2,
#    'review_palate': 1,
#    'review_taste': 3,
#    'review_overall': 3,
#    'review_profileName': 'Ringo',
#    'review_text': 'If regular Icehouse just does not fill your requirements for a crappy beer, you can always rely on this one.'}},
#  {'_index': 'beers',
#   '_id': '435433',
#   '_score': 12.429213,
#   '_source': {'beer_name': 'Keystone Ice',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '5.9',
#    'review_appearance': 1,
#    'review_aroma': 1,
#    'review_palate': 1,
#    'review_taste': 1,
#    'review_overall': 1,
#    'review_profileName': 'sanmiguel',
#    'review_text': 'Ugh. Like Icehouse, it is a shitty, poor university beer. Very watery and unappetising; and a metallic finish. To the bins!'}},
#  {'_index': 'beers',
#   '_id': '446940',
#   '_score': 12.429213,
#   '_source': {'beer_name': 'Icehouse Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '5',
#    'review_appearance': 2,
#    'review_aroma': 2,
#    'review_palate': 1,
#    'review_taste': 2,
#    'review_overall': 4,
#    'review_profileName': 'iamsancho16',
#    'review_text': 'I didnt really taste much of a difference between this and original Icehouse.  However, Id still prefer to drink Busch Ice.'}},
#  {'_index': 'beers',
#   '_id': '429726',
#   '_score': 12.310643,
#   '_source': {'beer_name': 'Icehouse Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '5',
#    'review_appearance': 1,
#    'review_aroma': 2,
#    'review_palate': 1,
#    'review_taste': 2,
#    'review_overall': 5,
#    'review_profileName': 'JLAudio',
#    'review_text': 'Not bad...a little worse than Icehouse but if you are cheap and are counting calories....ok then give it a whirl'}},
#  {'_index': 'beers',
#   '_id': '413081',
#   '_score': 11.858154,
#   '_source': {'beer_name': 'Red Dog',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '5',
#    'review_appearance': 2,
#    'review_aroma': 2,
#    'review_palate': 3,
#    'review_taste': 3,
#    'review_overall': 5,
#    'review_profileName': 'Bockyhorsey',
#    'review_text': 'King Can. Standard swill beer that is simular to Icehouse. Went down good while playing cards but wouldnt buy this as something to fill the fridge.'}},
#  {'_index': 'beers',
#   '_id': '240225',
#   '_score': 11.750181,
#   '_source': {'beer_name': 'Icehouse Light',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '5',
#    'review_appearance': 2,
#    'review_aroma': 2,
#    'review_palate': 2,
#    'review_taste': 3,
#    'review_overall': 5,
#    'review_profileName': 'Shag',
#    'review_text': 'Why make a lite ice beer? If you wanna drink icehouse you must want to get drunk right? Why settle on less alcohol? Please stop this nonsense!'}},
#  {'_index': 'beers',
#   '_id': '303322',
#   '_score': 11.750181,
#   '_source': {'beer_name': 'Budweiser',
#    'beer_style': 'Pale Lager',
#    'beer_ABV': '5',
#    'review_appearance': 2,
#    'review_aroma': 1,
#    'review_palate': 1,
#    'review_taste': 3,
#    'review_overall': 5,
#    'review_profileName': 'NobleSquirrel',
#    'review_text': 'UPDATED: JUN 16, 2007 Ummm, I cant think of anything to say about this beer other than it does actually taste better than Special Ex and Icehouse.'}}]

# %% [markdown]
# 1.9 Function for a fuzzy query on the beer name

# %%
def fuzzy_query(text, categ):
    exc = {
          "query": {
            "fuzzy" : {
              categ : {
                "value": text,
                "fuzziness": "AUTO"
              }
            }    
          }
        }
    return exc

# %%
# example on term bee in beer_name
fuzzy_bee = fuzzy_query('bee', "beer_name")
rd = e.curl('get', f'{index_name}/_search', fuzzy_bee)
rd.json()['hits']['hits']
# Out:
# [{'_index': 'beers',
#   '_id': '428202',
#   '_score': 5.6557846,
#   '_source': {'beer_name': 'Bees Honey Beer',
#    'beer_style': 'Golden Ale/Blond Ale',
#    'beer_ABV': '5.2',
#    'review_appearance': 3,
#    'review_aroma': 6,
#    'review_palate': 3,
#    'review_taste': 6,
#    'review_overall': 11,
#    'review_profileName': 'leaparsons',
#    'review_text': 'Cask, Newark Fest 08.  Golden with a smalll head.  Aromas are caramel, citrus and yeasty with some woody notes and dark honey.  Flavours are sweet caramel malts with yeast and citrus.  Honey sweetness on the finish.'}},
#  {'_index': 'beers',
#   '_id': '79822',
#   '_score': 5.318981,
#   '_source': {'beer_name': 'Barnsley Beer Company Bee By Gum',
#    'beer_style': 'Golden Ale/Blond Ale',
#    'beer_ABV': '4.3',
#    'review_appearance': 2,
#    'review_aroma': 6,
#    'review_palate': 3,
#    'review_taste': 7,
#    'review_overall': 13,
#    'review_profileName': 'rauchbier',
#    'review_text': 'Bottle, from Rhythm & Booze in Barton. Gold, thin shortlived white head and gentle condition. Big sweet floral aromas with touches of pineapple and peach, quite full in the mouth with an initial honey note giving way to a solid hop bitterness before the honey notes return with a lingering floral sweetness, long finish with pleasant balance between the powdery hop bitterness and the floral honey sweetnes'}},
#  {'_index': 'beers',
#   '_id': '541458',
#   '_score': 5.318981,
#   '_source': {'beer_name': 'Barnsley Beer Company Bee By Gum',
#    'beer_style': 'Golden Ale/Blond Ale',
#    'beer_ABV': '4.3',
#    'review_appearance': 4,
#    'review_aroma': 8,
#    'review_palate': 4,
#    'review_taste': 7,
#    'review_overall': 12,
#    'review_profileName': 'superdan35',
#    'review_text': 'Bought from rhythm and booze, they have a website to find your nearest store, www.rhythmandbooze.co.uk. Also, the barnsley beer company have a site with all their beers on there, along with food pairings. www.barnsleybeercompany.co.uk'}},
#  {'_index': 'beers',
#   '_id': '374371',
#   '_score': 5.0966,
#   '_source': {'beer_name': 'Breakside Margarets Beet Beer',
#    'beer_style': 'Spice/Herb/Vegetable',
#    'beer_ABV': '7',
#    'review_appearance': 5,
#    'review_aroma': 6,
#    'review_palate': 3,
#    'review_taste': 7,
#    'review_overall': 13,
#    'review_profileName': 'troopie',
#    'review_text': 'Pours red with medium white head.  Rather strong for a pilsener.  Grassy aroma, Hoppy flavour with beet sweetness.  Rather salady finish.  I was told this was a pilsener with beet juice.  Rather unique actually.'}},
#  {'_index': 'beers',
#   '_id': '34611',
#   '_score': 4.913396,
#   '_source': {'beer_name': 'Founders Honey Wheat (Bees Wax / Honey Bee)',
#    'beer_style': 'Wheat Ale',
#    'beer_ABV': '-',
#    'review_appearance': 3,
#    'review_aroma': 6,
#    'review_palate': 4,
#    'review_taste': 7,
#    'review_overall': 13,
#    'review_profileName': 'badnewsbeers',
#    'review_text': 'this is another substandard founders beer.....cloudy yellow hazy appearance with little white head...aroma is typical of a wheat with hints of honey and sugar...flavor is similar; nothing special here'}},
#  {'_index': 'beers',
#   '_id': '268835',
#   '_score': 4.913396,
#   '_source': {'beer_name': 'Barossa Valley Bee Sting Honey Wheat Beer',
#    'beer_style': 'Wheat Ale',
#    'beer_ABV': '5',
#    'review_appearance': 4,
#    'review_aroma': 6,
#    'review_palate': 3,
#    'review_taste': 6,
#    'review_overall': 9,
#    'review_profileName': 'Aarleks',
#    'review_text': 'Bottle: One of the great things about the emerging craftbeer or micro industry in Australia is the increasing number of small producers attempting to fill the gap between cheap lagers and serious attempts at quality. Why is this great? Well, by filling that gap talented brewers are freed up to produce unusual or challenging beers. This is one of those beers that fills the gap. It is relatively well made, inoffensive, but ultimatly not interesting to the beer enthusiast.Cloudy amber tinged gold with a solid white head.  Piney and citric hops initially dominate the aroma, though they are briefly joined by a bad-breath/rotting-gum note, and later a soapy honey presence. In the mouth a nice wheaty flavour with some pleasant clove phenolics sets up an elusive volatile honey heat. Theres also a honey oiliness, which isnt bad, but really theres nothing that grabs you.'}},
#  {'_index': 'beers',
#   '_id': '364212',
#   '_score': 4.913396,
#   '_source': {'beer_name': 'Founders Honey Wheat (Bees Wax / Honey Bee)',
#    'beer_style': 'Wheat Ale',
#    'beer_ABV': '-',
#    'review_appearance': 4,
#    'review_aroma': 6,
#    'review_palate': 4,
#    'review_taste': 6,
#    'review_overall': 13,
#    'review_profileName': 'xnoxhatex',
#    'review_text': 'On tap at the brewpub.  Cloudy straw with creamy white head.  Aroma is off dry wheat and citrus with some sulphur.  Flavor is sweeter peach, wheat, citrus, a little sulphur again with spice, honey, nice.  Medium, creamy body.  The honey is there but well blended with the rest of the beer, well done and sessionable.'}},
#  {'_index': 'beers',
#   '_id': '387289',
#   '_score': 4.913396,
#   '_source': {'beer_name': 'Barossa Valley Bee Sting Honey Wheat Beer',
#    'beer_style': 'Wheat Ale',
#    'beer_ABV': '5',
#    'review_appearance': 3,
#    'review_aroma': 6,
#    'review_palate': 4,
#    'review_taste': 6,
#    'review_overall': 10,
#    'review_profileName': 'highlandlad',
#    'review_text': 'I want a job writing beer labels. No prior experience needed. All you do is take the following words and phrases and assemble them in the right order: "finest natural ingredients", "quality", "tradition", "premium beer", "citrus". Thats what it looks like they did with this label. They get bonus points for managing to use "premium" and "finest" twice. Fortunately, the beer is less predictable. Its a hazy sugar-cane gold with a rocky head showing moderate length. The sweet aroma packs plenty of honey, bananas and bubblegum. Smells fresh and suspiciously like it really does contain honey. Take a sip and you know for sure it does. At room temperature this has a surprisingly fat, creamy mouthfeel - very nice indeed. Lots of honey sugars, mashed banana and sour wheat notes before an intrusive late bitter wash that doesnt suit the style. Very salty finish with a pinch of pepper for good measure. This was much better than expected. (330ml bottle from Liquor on Parade, Sydney)'}},
#  {'_index': 'beers',
#   '_id': '391326',
#   '_score': 4.913396,
#   '_source': {'beer_name': 'Barossa Valley Bee Sting Honey Wheat Beer',
#    'beer_style': 'Wheat Ale',
#    'beer_ABV': '5',
#    'review_appearance': 2,
#    'review_aroma': 6,
#    'review_palate': 3,
#    'review_taste': 5,
#    'review_overall': 11,
#    'review_profileName': 'davidm',
#    'review_text': 'Bottle 330ml. Pretty unbalanced. Aromas of leaves, hay, and a hint of honey. Taste is sweet and sour. Palate is oily, with a thin-to-medium body. Yellow, cloudy, with a thin head.'}},
#  {'_index': 'beers',
#   '_id': '494382',
#   '_score': 4.913396,
#   '_source': {'beer_name': 'Barossa Valley Bee Sting Honey Wheat Beer',
#    'beer_style': 'Wheat Ale',
#    'beer_ABV': '5',
#    'review_appearance': 2,
#    'review_aroma': 6,
#    'review_palate': 2,
#    'review_taste': 5,
#    'review_overall': 10,
#    'review_profileName': 'mkel07',
#    'review_text': 'Bottle. Poured with a nice head, with a wheat and honey aroma. Sweet flavour with light hop aftertaste.Quite okay for a honey wheat beer.'}}]

# %% [markdown]
# 1.10 Function for a full-text query on the review text, with results sorted by decreasing rating on the beer aroma
# (highest to lowest)

# %%
def ft_sorted_query(text, categ, filter, sort_order):
    exc = {
      "query": {
        "match" : {
           categ: text
          }
        },
        "sort" : [
              { filter : {"order" : sort_order}}
       ]
    }
    return exc

# %%
# example on IPA beers
ft_ipa_sort = ft_sorted_query('IPA', "review_text", "review_aroma", "desc")
red = e.curl('get', f'{index_name}/_search', ft_ipa_sort)
red.json()['hits']['hits']
# Out:
# [{'_index': 'beers',
#   '_id': '2084',
#   '_score': None,
#   '_source': {'beer_name': 'Samuel Adams Imperial Pilsner',
#    'beer_style': 'Strong Pale Lager/Imperial Pils',
#    'beer_ABV': '8.8',
#    'review_appearance': 4,
#    'review_aroma': 10,
#    'review_palate': 5,
#    'review_taste': 9,
#    'review_overall': 19,
#    'review_profileName': 'redave',
#    'review_text': 'This may not have been "*the* hoppiest beer in the world."  But it is definitely "one of the hoppiest beers in the world.", certainly for a lager!\t24 oz bottle.    [Man i whish Id bought a case]\tVery orange  amberish color.  surprisingly white creamy head, with good retention.\tIm not sure what i was expecting, but this was IT!  Very IPA grassy / flower nose.  Wonderful crisp, hoppy lager [much more crisp than the DFH imperial pilsner Ive had] spicy and some malt.\tThis is exactly what Id want if i ever thought of an IPA Pilsner.\tCant wait til next year.  [dont disappoint me Jim]'},
#   'sort': [10]},
#  {'_index': 'beers',
#   '_id': '4279',
#   '_score': None,
#   '_source': {'beer_name': 'Three Floyds Dreadnaught Imperial IPA',
#    'beer_style': 'Imperial/Double IPA',
#    'beer_ABV': '9.5',
#    'review_appearance': 4,
#    'review_aroma': 10,
#    'review_palate': 5,
#    'review_taste': 9,
#    'review_overall': 18,
#    'review_profileName': 'PolakPorter',
#    'review_text': 'Deliciousness and delicocity combined. Best IPA Ive had to date. So good I want to do dirty things to it. Aroma is oh so fruity and the taste clings to the tastebuds for days. Mmmmmmmmmmmmmmm....love this beer. Just wish I could afford more of it'},
#   'sort': [10]},
#  {'_index': 'beers',
#   '_id': '9523',
#   '_score': None,
#   '_source': {'beer_name': 'Weyerbacher Hops Infusion',
#    'beer_style': 'India Pale Ale (IPA)',
#    'beer_ABV': '6.2',
#    'review_appearance': 5,
#    'review_aroma': 10,
#    'review_palate': 4,
#    'review_taste': 9,
#    'review_overall': 19,
#    'review_profileName': 'garrison',
#    'review_text': 'From a bottle (from a six pack my loving girlfriend purchased for me on my birthday) - Thiis one poured a dark amber liquid with a spicey aroma and a lasting, fine-bubbled white head. Tastewise, it was a hops-heavy delight, with noticeable piney and citrus-like untertones... a very decent IPA, in other words!'},
#   'sort': [10]},
#  {'_index': 'beers',
#   '_id': '9722',
#   '_score': None,
#   '_source': {'beer_name': 'Alt Platz Scourge of Olde Town I.P.A.',
#    'beer_style': 'India Pale Ale (IPA)',
#    'beer_ABV': '5.9',
#    'review_appearance': 3,
#    'review_aroma': 10,
#    'review_palate': 3,
#    'review_taste': 7,
#    'review_overall': 17,
#    'review_profileName': 'geoffreyfox99',
#    'review_text': 'I dont like IPAs, but I know what it supposed to be, and this is a good IPA.  A slight dyactel or oily flavor, but it wasnt too bad.  If you like IPA, you will like this beer.'},
#   'sort': [10]},
#  {'_index': 'beers',
#   '_id': '11121',
#   '_score': None,
#   '_source': {'beer_name': 'Dogfish Head 90 Minute Imperial IPA',
#    'beer_style': 'Imperial/Double IPA',
#    'beer_ABV': '9',
#    'review_appearance': 5,
#    'review_aroma': 10,
#    'review_palate': 5,
#    'review_taste': 10,
#    'review_overall': 19,
#    'review_profileName': 'bdk',
#    'review_text': 'This Imperial IPA is so good I dont care what it looks like, but it is pretty. Super hoppy but no harsh bitterness. Smooth finish. Will make Sam Adams BL taste like water after you had one of these.'},
#   'sort': [10]},
#  {'_index': 'beers',
#   '_id': '11271',
#   '_score': None,
#   '_source': {'beer_name': 'Flying Dog Double Dog Double Pale Ale',
#    'beer_style': 'American Strong Ale',
#    'beer_ABV': '11.5',
#    'review_appearance': 5,
#    'review_aroma': 10,
#    'review_palate': 4,
#    'review_taste': 9,
#    'review_overall': 19,
#    'review_profileName': 'williamherbert',
#    'review_text': 'Big, thick and cloudy. A big finger of head. Dark orange, dark in the thick spots of the glass. Its beautiful and murky.\t\tWonderful sweet, woody, grassy West Coast hops. There are some grassy pale malts that compliment it tremendously. Magnificent, fragrant perfume hops. Nearly perfect.\t\tFlowery, citrusy, bitter but sweet. The malts are roasted, and also bitter. The back of the tongue stays bitter throughout. The hops in this beer are very reminiscent of Stone Ruination for comparison.\t\tCreamy, fizzy, thick and lasting.\t\tAgain, very similar to Stone Ruination, and nothing wrong with that. This is a challenging, tremendous IPA.'},
#   'sort': [10]},
#  {'_index': 'beers',
#   '_id': '12264',
#   '_score': None,
#   '_source': {'beer_name': 'Bells Hopslam',
#    'beer_style': 'Imperial/Double IPA',
#    'beer_ABV': '10',
#    'review_appearance': 5,
#    'review_aroma': 10,
#    'review_palate': 5,
#    'review_taste': 10,
#    'review_overall': 20,
#    'review_profileName': 'tugg407',
#    'review_text': 'UPDATED: FEB 11, 2010 $16 SIX PACK FROM TOTAL WINE,  WORTH EVERY PENNY!   MY FAV. IPA\tIVE LIKED EVERYTHING  FROM THE BELLS BREWERY SO FAR'},
#   'sort': [10]},
#  {'_index': 'beers',
#   '_id': '12393',
#   '_score': None,
#   '_source': {'beer_name': 'Bells Hopslam',
#    'beer_style': 'Imperial/Double IPA',
#    'beer_ABV': '10',
#    'review_appearance': 5,
#    'review_aroma': 10,
#    'review_palate': 4,
#    'review_taste': 8,
#    'review_overall': 18,
#    'review_profileName': 'Styles',
#    'review_text': 'UPDATED: MAR 31, 2007 Orangish amber in color, huge semi rocky, off-white head, great lacing. Poured into a GI IPA glass, has perfect appearance. Aroma has all kinds of carribean fruit up front, mango, pineapple, peach, tangerine some lemon and orange zest. Malt backbone lacks a bit, assuming bigger than aroma indicates, because at 9.5% there is no alcohol detectable whatsoever. Flavor again all kinds of fruit and citrus zest. Lots of resins, first time pine shows up at all, is in the finish. I dont get much malt, but not all too unbalanced. Great oily/sticky mouthfeel. My daily drinker right now, cant get enough of the stuff. Re-rate batch 7775, huge pine through and through, would score 9/5/8/4/17-4.3, still very nice, just prefer the huge fruit characters. Most always keep the higher rating though.'},
#   'sort': [10]},
#  {'_index': 'beers',
#   '_id': '17463',
#   '_score': None,
#   '_source': {'beer_name': 'Goose Island Imperial IPA',
#    'beer_style': 'Imperial/Double IPA',
#    'beer_ABV': '9.2',
#    'review_appearance': 5,
#    'review_aroma': 10,
#    'review_palate': 4,
#    'review_taste': 9,
#    'review_overall': 18,
#    'review_profileName': 'apoptosis',
#    'review_text': 'Quite a delicious IPA for sure.  the body is crystal clear, orange body, with a lightly frothed, frosty white head.  The aroma is strong with fruits, especially peaches, apricots and hops.  The flavor is bursting with grapefruits and citrus, with just the perfect amount of sweetness to compliment the hoppy bitterness.  Delicious - not too sweet, not too bitter, nicely balanced and very refreshing.  THe only problem here is that it goes down so smoothly, that its difficult to keep in mind the -OH content.'},
#   'sort': [10]},
#  {'_index': 'beers',
#   '_id': '19346',
#   '_score': None,
#   '_source': {'beer_name': 'Moylans Hopsickle Imperial India Pale Ale',
#    'beer_style': 'Imperial/Double IPA',
#    'beer_ABV': '9.2',
#    'review_appearance': 3,
#    'review_aroma': 10,
#    'review_palate': 3,
#    'review_taste': 7,
#    'review_overall': 15,
#    'review_profileName': 'nhorween',
#    'review_text': 'UPDATED: MAR 24, 2007 Bottle.  Clear copper color with a off-white head.  Amazing floral aroma that is super grassy and piney, maybe the best aroma Ive ever gotten from an IPA.  Very bitter flavor that doesnt live up to its aroma.  Still very balanced with a nice mouthfeel and good carbonation.  Rerate... hopmonster.  Great great aroma, but the flavor is hugely bitter and unbalanced.'},
#   'sort': [10]}]
